# %%
# !pip install -U google-genai
# Out:
# Requirement already satisfied: google-genai in /usr/local/lib/python3.13/dist-packages (2.12.1)
# Collecting google-genai
#   Downloading google_genai-2.22.0-py3-none-any.whl.metadata (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 kB 1.6 MB/s eta 0:00:00
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in /usr/local/lib/python3.13/dist-packages (from google-genai) (4.14.2)
# Collecting google-auth<3.0.0,>=2.56.0 (from google-auth[requests]<3.0.0,>=2.56.0->google-genai)
#   Downloading google_auth-2.57.1-py3-none-any.whl.metadata (6.0 kB)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in /usr/local/lib/python3.13/dist-packages (from google-genai) (0.28.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.12.5 in /usr/local/lib/python3.13/dist-packages (from google-genai) (2.13.4)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in /usr/local/lib/python3.13/dist-packages (from google-genai) (2.32.4)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in /usr/local/lib/python3.13/dist-packages (from google-genai) (9.1.4)
# Requirement already satisfied: websockets<17.0,>=13.0.0 in /usr/local/lib/python3.13/dist-packages (from google-genai) (15.0.1)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.14.0 in /usr/local/lib/python3.13/dist-packages (from google-genai) (4.16.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.13/dist-packages (from google-genai) (1.9.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.13/dist-packages (from google-genai) (1.3.1)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.13/dist-packages (from anyio<5.0.0,>=4.8.0->google-genai) (3.19)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.13/dist-packages (from google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in /usr/local/lib/python3.13/dist-packages (from google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai) (50.0.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.13/dist-packages (from httpx<1.0.0,>=0.28.1->google-genai) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.13/dist-packages (from httpx<1.0.0,>=0.28.1->google-genai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.13/dist-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.13/dist-packages (from pydantic<3.0.0,>=2.12.5->google-genai) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /usr/local/lib/python3.13/dist-packages (from pydantic<3.0.0,>=2.12.5->google-genai) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.13/dist-packages (from pydantic<3.0.0,>=2.12.5->google-genai) (0.4.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.13/dist-packages (from requests<3.0.0,>=2.28.1->google-genai) (3.4.9)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.13/dist-packages (from requests<3.0.0,>=2.28.1->google-genai) (2.5.0)
# Requirement already satisfied: cffi>=2.0.0 in /usr/local/lib/python3.13/dist-packages (from cryptography>=38.0.3->google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai) (2.1.1)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.13/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai) (0.6.4)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.13/dist-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai) (3.0)
# Downloading google_genai-2.22.0-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 17.4 MB/s eta 0:00:00
# Downloading google_auth-2.57.1-py3-none-any.whl (259 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 260.0/260.0 kB 7.8 MB/s eta 0:00:00
# Installing collected packages: google-auth, google-genai
#   Attempting uninstall: google-auth
#     Found existing installation: google-auth 2.49.0
#     Uninstalling google-auth-2.49.0:
#       Successfully uninstalled google-auth-2.49.0
#   Attempting uninstall: google-genai
#     Found existing installation: google-genai 2.12.1
#     Uninstalling google-genai-2.12.1:
#       Successfully uninstalled google-genai-2.12.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires google-auth==2.49.0, but you have google-auth 2.57.1 which is incompatible.
# Successfully installed google-auth-2.57.1 google-genai-2.22.0

# %%
from google import genai

# %%
from google.colab import userdata
from google import genai

client = genai.Client(api_key=userdata.get("GEMINI_API_KEY"))

print("Gemini client connected successfully!")
# Out:
# Gemini client connected successfully!

# %%
MODEL = "gemini-3.5-flash"
print("Model selected:", MODEL)
# Out:
# Model selected: gemini-3.5-flash

# %%
response = client.models.generate_content(
    model=MODEL,
    contents="Hello"
)

print(response.text)
# Out:
# Hello! How can I help you today?

# %%
print("Gemini Chatbot (type 'exit' to quit)\n")

while True:
    user_input = input("You: ")

    # Exit condition
    if user_input.lower() in ["exit", "quit", "bye"]:
        print("Chatbot: Goodbye 👋")
        break

    # Send input to Gemini
    response = client.models.generate_content(
        model=MODEL,
        contents=user_input
    )

    # Print response
    print("Chatbot:", response.text)
# Out:
# Gemini Chatbot (type 'exit' to quit)
#
# You: What is artificial intelligence ?
# Chatbot: At its simplest, **Artificial Intelligence (AI)** is a branch of computer science that focuses on building smart machines capable of performing tasks that typically require human intelligence.
#
# These tasks include things like learning, reasoning, problem-solving, understanding natural language, and recognizing visual patterns.
#
# Here is a breakdown of how AI works, its different types, and how it is used today.
#
# ---
#
# ### 1. How Does AI Work?
# Traditional computer programs rely on strict, "if-then" rules written by humans. AI, however, uses **data and algorithms** to learn how to do things on its own.
#
# The relationship between different AI concepts is often described like a Russian nesting doll:
#
# *   **Artificial Intelligence:** The broad concept of machines acting intelligently.
# *   **Machine Learning (ML):** A subset of AI. Instead of writing code with specific instructions, you feed a computer a massive amount of data, and the computer uses algorithms to "learn" the patterns and make decisions.
# *   **Deep Learning (DL):** A subset of ML. It uses "neural networks" (structures inspired by the human brain) to solve highly complex problems, like translating languages, driving self-driving cars, or identifying tumors in X-rays.
#
# ---
#
# ### 2. The Types of AI
# AI is generally categorized into three levels of capability:
#
# 1.  **Narrow AI (Weak AI):** This is the only type of AI that exists today. It is designed to perform a specific, single task extremely well (e.g., facial recognition, searching the web, or playing chess). It has no consciousness or general intelligence.
# 2.  **General AI (Strong AI / AGI):** This is a hypothetical level of AI. An AGI would possess human-level intelligence, meaning it could understand, learn, and apply knowledge across any intellectual task just like a human.
# 3.  **Super AI (ASI):** A theoretical future AI that would surpass human intelligence in every possible way, from scientific creativity to social skills.
#
# ---
#
# ### 3. Everyday Examples of AI
# You likely interact with AI multiple times a day without realizing it:
#
# *   **Generative AI:** Tools like **ChatGPT**, Gemini, or Midjourney that can generate original text, images, music, and computer code.
# *   **Smart Assistants:** Siri, Alexa, and Google Assistant, which use natural language processing to understand your voice commands.
# *   **Recommendation Systems:** The algorithms used by Netflix, Spotify, TikTok, and Amazon to suggest what you should watch, listen to, or buy next.
# *   **Navigation:** Google Maps or Apple Maps calculating the fastest route based on real-time traffic data.
# *   **Facial Recognition:** Unlocking your phone with your face.
# *   **Finance:** Algorithms used by banks to detect fraudulent credit card transactions in real-time.
#
# ---
#
# ### 4. Why is AI Important? (The Pros)
# *   **Automation:** It can handle repetitive, boring, or dangerous tasks, freeing humans to do more creative work.
# *   **Speed and Accuracy:** Computers can analyze massive amounts of data in seconds, finding patterns that would take humans years to discover (especially useful in medicine and climate science).
# *   **24/7 Availability:** AI systems don't need sleep, breaks, or food.
#
# ### 5. Risks and Ethical Concerns (The Cons)
# As AI grows more powerful, it presents significant challenges:
# *   **Job Displacement:** AI automation could replace jobs in sectors like customer service, writing, coding, and manufacturing.
# *   **Bias:** AI learns from human data. If the data contains historical biases (racial, gender, etc.), the AI will replicate and scale those biases.
# *   **Deepfakes and Misinformation:** AI can create highly realistic fake videos, audio, and news, making it hard to trust digital information.
# *   **Privacy:** AI systems require vast amounts of personal data to train, raising concerns about surveillance and data security.
#
# ### Summary
# Artificial Intelligence is not a single technology, but a collection of technologies that allow computers to mimic human-like cognitive functions. It is currently transforming every industry on Earth, from healthcare and education to entertainment and finance.
